# %%
import pstats
p = pstats.Stats('/Users/xwan0069/Desktop/Projects/Simulator_Ricardo/30mins_result.out')

# strip_dirs(): 去掉无关的路径信息
# sort_stats(): 排序，支持的方式和上述的一致
# print_stats(): 打印分析结果，可以指定打印前几行

# 和直接运行cProfile.run("test()")的结果是一样的
p.strip_dirs().sort_stats(-1).print_stats()
# Out:
# Wed May  1 17:09:04 2024    /Users/xwan0069/Desktop/Projects/Simulator_Ricardo/30mins_result.out
#
#          513886438 function calls (513886097 primitive calls) in 136.171 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      18/6    0.000    0.000    0.013    0.002 <frozen importlib._bootstrap>:1002(_find_and_load)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1018(_gcd_import)
#      15/7    0.000    0.000    0.007    0.001 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#        28    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:112(release)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:152(__init__)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:156(__enter__)
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:160(__exit__)
# ...

# %%
# 按照函数名排序，只打印前3行函数的信息, 参数还可为小数,表示前百分之几的函数信息 
p.strip_dirs().sort_stats("name").print_stats(3)

# %%
# 按照运行时间进行排序
p.strip_dirs().sort_stats("cumtime").print_stats()
# Out:
# Wed May  1 17:09:04 2024    /Users/xwan0069/Desktop/Projects/Simulator_Ricardo/30mins_result.out
#
#          513886438 function calls (513886097 primitive calls) in 136.171 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      12/1    0.000    0.000  136.172  136.172 {built-in method builtins.exec}
#         1    0.000    0.000  136.171  136.171 main.py:12(run_sim)
#         1    0.000    0.000  136.064  136.064 Simulator_platform.py:90(run_simulation)
#        60    0.028    0.000  136.037    2.267 Simulator_platform.py:107(run_cycle)
#        60    0.018    0.000   83.976    1.400 dispatch_sba.py:9(assign_orders_through_sba)
#        60    1.874    0.031   73.749    1.229 dispatch_sba.py:46(compute_candidate_veh_req_pairs)
#  14612869    3.081    0.000   65.669    0.000 route_functions.py:49(get_timeCost)
#     45397    0.402    0.000   60.998    0.001 scheduling.py:12(compute_schedule)
# ...

# %%
# 如果想知道有哪些函数调用了sum_num
p.print_callers(0.5, "sum_num")

# %%
# 查看test()函数中调用了哪些函数
p.print_callees("ilp").sort_stats("cumtime").print_stats()

# %%
import pickle
import time
schedule = [a for a in range(100000000)]
PU_node = ['a']
DO_node = ['b']
PU_node_position = 2
DO_node_position = 5

# %%
start = time.time()
for i in range (0,10):
    time.time()
    new_schedule =pickle.loads(pickle.dumps(schedule))  #must use deepcopy. otherwise will stuck in infinite loop
    new_schedule.insert(PU_node_position, PU_node)
    new_schedule.insert(DO_node_position, DO_node)
end = time.time()
print(end-start)

# %%
start = time.time()
for i in range(0,10):
    new_schedule = schedule
    new_schedule_part1 = new_schedule[:PU_node_position]
    new_schedule_part2 = new_schedule[PU_node_position:]
    new_schedule_part1.append(PU_node)
    new_schedule_part1.extend(new_schedule_part2)

    new_schedule_part3 = new_schedule_part1[:DO_node_position]
    new_schedule_part4 = new_schedule_part1[DO_node_position:]
    new_schedule_part3.append(DO_node)
    new_schedule_part3.extend(new_schedule_part4)

end = time.time()
print(end-start)

# %%
new_schedule_part2

# %%
for i in range(10):
    print(i)
    if i == 5:
        break
print('done')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# done
